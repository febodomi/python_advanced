# %%
import requests
import pandas as pd
import numpy as np
import json
from AlphaVantage import API_KEY

# %%
# https://www.alphavantage.co/documentation/
# https://requests.readthedocs.io/en/master/user/quickstart/

# %%
print(API_KEY)
# Out:
# J0P7QM3MWIZ3WGHY

# %%
response=requests.get('https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=**APIKEY***&datatype=json')

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{\n    "Meta Data": {\n        "1. Information": "Intraday (5min) open, high, low, close prices and volume",\n        "2. Symbol": "IBM",\n        "3. Last Refreshed": "2021-03-23 19:35:00",\n        "4. Interval": "5min",\n        "5. Output Size": "Compact",\n        "6. Time Zone": "US/Eastern"\n    },\n    "Time Series (5min)": {\n        "2021-03-23 19:35:00": {\n            "1. open": "130.4000",\n            "2. high": "130.4000",\n            "3. low": "130.4000",\n            "4. close": "130.4000",\n            "5. volume": "134"\n        },\n        "2021-03-23 18:10:00": {\n            "1. open": "130.4100",\n            "2. high": "130.4100",\n            "3. low": "130.4100",\n            "4. close": "130.4100",\n            "5. volume": "250"\n        },\n        "2021-03-23 17:50:00": {\n            "1. open": "130.7499",\n            "2. high": "130.7499",\n            "3. low": "130.7499",\n            "4. close": "130.7499",\n            "5. volume": "201"\n      
# ...

# %%
response.json()
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2021-03-23 19:35:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2021-03-23 19:35:00': {'1. open': '130.4000',
#    '2. high': '130.4000',
#    '3. low': '130.4000',
#    '4. close': '130.4000',
#    '5. volume': '134'},
#   '2021-03-23 18:10:00': {'1. open': '130.4100',
#    '2. high': '130.4100',
#    '3. low': '130.4100',
#    '4. close': '130.4100',
#    '5. volume': '250'},
#   '2021-03-23 17:50:00': {'1. open': '130.7499',
#    '2. high': '130.7499',
#    '3. low': '130.7499',
#    '4. close': '130.7499',
#    '5. volume': '201'},
#   '2021-03-23 17:25:00': {'1. open': '130.8000',
#    '2. high': '130.8000',
#    '3. low': '130.8000',
#    '4. close': '130.8000',
#    '5. volume': '300'},
#   '2021-03-23 17:15:00': {'1. open': '130.8400',
# ...

# %%
parameters={'function':'TIME_SERIES_INTRADAY', 'symbol':'IBM', 'interval':'5min', 'apikey':API_KEY, 'datatype':'json'}
data=requests.get('https://www.alphavantage.co/query?', params=parameters)

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2021-03-23 19:35:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2021-03-23 19:35:00': {'1. open': '130.4000',
#    '2. high': '130.4000',
#    '3. low': '130.4000',
#    '4. close': '130.4000',
#    '5. volume': '134'},
#   '2021-03-23 18:10:00': {'1. open': '130.4100',
#    '2. high': '130.4100',
#    '3. low': '130.4100',
#    '4. close': '130.4100',
#    '5. volume': '250'},
#   '2021-03-23 17:50:00': {'1. open': '130.7499',
#    '2. high': '130.7499',
#    '3. low': '130.7499',
#    '4. close': '130.7499',
#    '5. volume': '201'},
#   '2021-03-23 17:25:00': {'1. open': '130.8000',
#    '2. high': '130.8000',
#    '3. low': '130.8000',
#    '4. close': '130.8000',
#    '5. volume': '300'},
#   '2021-03-23 17:15:00': {'1. open': '130.8400',
# ...

# %%
data=response.json()

# %%
data['Meta Data']
# Out:
# {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2021-03-23 19:35:00',
#  '4. Interval': '5min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
data['Time Series (5min)']
# Out:
# {'2021-03-23 19:35:00': {'1. open': '130.4000',
#   '2. high': '130.4000',
#   '3. low': '130.4000',
#   '4. close': '130.4000',
#   '5. volume': '134'},
#  '2021-03-23 18:10:00': {'1. open': '130.4100',
#   '2. high': '130.4100',
#   '3. low': '130.4100',
#   '4. close': '130.4100',
#   '5. volume': '250'},
#  '2021-03-23 17:50:00': {'1. open': '130.7499',
#   '2. high': '130.7499',
#   '3. low': '130.7499',
#   '4. close': '130.7499',
#   '5. volume': '201'},
#  '2021-03-23 17:25:00': {'1. open': '130.8000',
#   '2. high': '130.8000',
#   '3. low': '130.8000',
#   '4. close': '130.8000',
#   '5. volume': '300'},
#  '2021-03-23 17:15:00': {'1. open': '130.8400',
#   '2. high': '130.8500',
#   '3. low': '130.8400',
#   '4. close': '130.8500',
#   '5. volume': '400'},
#  '2021-03-23 16:50:00': {'1. open': '130.5000',
#   '2. high': '130.5000',
#   '3. low': '130.4000',
#   '4. close': '130.4000',
#   '5. volume': '1239'},
#  '2021-03-23 16:20:00': {'1. open': '130.4600',
# ...

# %%
for date in data['Time Series (5min)'].keys():
    print(date)
# Out:
# 2021-03-23 19:35:00
# 2021-03-23 18:10:00
# 2021-03-23 17:50:00
# 2021-03-23 17:25:00
# 2021-03-23 17:15:00
# 2021-03-23 16:50:00
# 2021-03-23 16:20:00
# 2021-03-23 16:10:00
# 2021-03-23 16:05:00
# 2021-03-23 16:00:00
# 2021-03-23 15:55:00
# 2021-03-23 15:50:00
# 2021-03-23 15:45:00
# 2021-03-23 15:40:00
# 2021-03-23 15:35:00
# 2021-03-23 15:30:00
# 2021-03-23 15:25:00
# 2021-03-23 15:20:00
# 2021-03-23 15:15:00
# 2021-03-23 15:10:00
# 2021-03-23 15:05:00
# 2021-03-23 15:00:00
# 2021-03-23 14:55:00
# 2021-03-23 14:50:00
# 2021-03-23 14:45:00
# 2021-03-23 14:40:00
# 2021-03-23 14:35:00
# 2021-03-23 14:30:00
# 2021-03-23 14:25:00
# 2021-03-23 14:20:00
# 2021-03-23 14:15:00
# 2021-03-23 14:10:00
# 2021-03-23 14:05:00
# 2021-03-23 14:00:00
# 2021-03-23 13:55:00
# 2021-03-23 13:50:00
# 2021-03-23 13:45:00
# 2021-03-23 13:40:00
# 2021-03-23 13:35:00
# 2021-03-23 13:30:00
# 2021-03-23 13:25:00
# 2021-03-23 13:20:00
# 2021-03-23 13:15:00
# 2021-03-23 13:10:00
# 2021-03-23 13:05:00
# ...

# %%
df=pd.DataFrame.from_dict(data['Time Series (5min)'])

# %%
df=pd.DataFrame.from_dict(data['Time Series (5min)'], orient='index')
df.head()
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2021-03-23 19:35:00  130.4000  130.4000  130.4000  130.4000       134
# 2021-03-23 18:10:00  130.4100  130.4100  130.4100  130.4100       250
# 2021-03-23 17:50:00  130.7499  130.7499  130.7499  130.7499       201
# 2021-03-23 17:25:00  130.8000  130.8000  130.8000  130.8000       300
# 2021-03-23 17:15:00  130.8400  130.8500  130.8400  130.8500       400

# %%
df.rename(columns={'1. open':'Open','2. high':'High', '3. low':'Low', '4. close':'Close', '5. volume':'Volume' }, inplace=True)
df.head()
# Out:
#                          Open      High       Low     Close Volume
# 2021-03-23 19:35:00  130.4000  130.4000  130.4000  130.4000    134
# 2021-03-23 18:10:00  130.4100  130.4100  130.4100  130.4100    250
# 2021-03-23 17:50:00  130.7499  130.7499  130.7499  130.7499    201
# 2021-03-23 17:25:00  130.8000  130.8000  130.8000  130.8000    300
# 2021-03-23 17:15:00  130.8400  130.8500  130.8400  130.8500    400

# %%
df
# Out:
#                          Open      High       Low     Close Volume
# 2021-03-23 19:35:00  130.4000  130.4000  130.4000  130.4000    134
# 2021-03-23 18:10:00  130.4100  130.4100  130.4100  130.4100    250
# 2021-03-23 17:50:00  130.7499  130.7499  130.7499  130.7499    201
# 2021-03-23 17:25:00  130.8000  130.8000  130.8000  130.8000    300
# 2021-03-23 17:15:00  130.8400  130.8500  130.8400  130.8500    400
# ...                       ...       ...       ...       ...    ...
# 2021-03-23 08:20:00  130.3900  130.5400  130.3500  130.5400   6048
# 2021-03-23 08:15:00  130.0100  130.0100  130.0100  130.0100    500
# 2021-03-23 08:05:00  130.0100  130.0100  130.0000  130.0000   1654
# 2021-03-22 19:40:00  130.3600  130.3600  130.3600  130.3600    289
# 2021-03-22 19:10:00  130.3600  130.3600  130.3600  130.3600    171
#
# [100 rows x 5 columns]

# %%
url='https://www.alphavantage.co/query?function=CRYPTO_RATING&symbol=BTC&apikey=demo'

parameters={'function':'CRYPTO_RATING', 'symbol':'BTC','apikey':API_KEY, 'datatype':'json'}
data=requests.get('https://www.alphavantage.co/query?', params=parameters).json()

# %%
data
# Out:
# {'Note': 'Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.'}

# %%
url='https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=tesco&apikey=demo'

parameters={'function':'SYMBOL_SEARCH','apikey':API_KEY, 'keywords':'facebook'}

data=requests.get('https://www.alphavantage.co/query?', params=parameters).json()

# %%
data
# Out:
# {'bestMatches': [{'1. symbol': 'FB2A.DEX',
#    '2. name': 'Facebook',
#    '3. type': 'Equity',
#    '4. region': 'XETRA',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'FB2A.FRK',
#    '2. name': 'Facebook',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'FBOK34.SAO',
#    '2. name': 'Facebook',
#    '3. type': 'Equity',
#    '4. region': 'Brazil/Sao Paolo',
#    '5. marketOpen': '10:00',
#    '6. marketClose': '17:30',
#    '7. timezone': 'UTC-03',
#    '8. currency': 'BRL',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'FB',
#    '2. name': 'Facebook Inc - Class A',
#    '3. type': 'Equity',
#    '4. region': 'United States',
#    '5. marketOpen': '09:30',
# ...

# %%
parameters={'function':'TIME_SERIES_INTRADAY', 'symbol':'FB', 'interval':'5min', 'apikey':API_KEY, 'datatype':'json'}

data=requests.get('https://www.alphavantage.co/query?', params=parameters).json()

# %%
data
# Out:
# {'Note': 'Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.'}
